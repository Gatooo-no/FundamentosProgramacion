# %% [markdown]
# <a href="https://colab.research.google.com/github/Gatooo-no/FundamentosProgramacion/blob/main/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 5
X = "Hola Mundo"
X = True
print("El valor de X es", X)
# Out:
# El valor de X es True
