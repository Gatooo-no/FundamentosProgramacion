# %% [markdown]
# <a href="https://colab.research.google.com/github/Gatooo-no/FundamentosProgramacion/blob/main/Unidad1/SPrestamos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingeneria en Sistemas Computacionales**
# ## **Fundamentos de progrmacion**
# ## **Unidad 1**
# ### Sistemas de Gestión de prestamos y reservaciones de computadoras - Versión 1
# Docente: **José Grabiel Rodriguez Rivas**
#
# Alumno: **Carlos Efrén Hernández Gámiz**

# %%
#Sistemas de prestamos
#Programacion basica

#Alumnos que estan en el sistema
alumnos =["26040220", "26040221", "26040222", "26040223", "26040224"]

#Cada caloer en la lista tiene si liste correspondiente con el alunmo
computadoras =["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
               "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
               "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]
aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"]
software =["Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB",
           "Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB",
           "Python, VS Code", "Python, Java VS Code", "AutoCAD, MATLAB", "Python, VS Code"]
estados = ["Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada", "Mantenimiento"]

#MENÚ PRINCIPAL
#USAMNOS EL WHILE PARA QUE SE REPITA INDEFINIDAMENTE HASTA QUE EL USARIA
#TECLEE LA OPCION 7 QUE ES SALIR O CUALQUIER OTRO MAYOR QUE 7
opcion = 0
while opcion <= 6:
  print("=============================")
  print("   SISTEMAS DE PRESTAMOS")
  print("=============================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar préstamo")
  print("4. Devolver computadora")
  print("5. Crear reservavión")
  print("6. Agregar computadora")
  print("7. Salir")
  opcion = int(input("Seleccione una opción: "))
  print("=============================")

#1. Consultar computadoras
if opcion == 1:
  print("---COMPUTADORAS---")
  for i in range(len(computadoras)):
    print("Aula: ", aulas[i])
    print("ID", computadoras[i])
    print("Software: ", software[i])
    print("Estado: ", estados[i])
    print("=============================")
#Buscar se software
elif opcion == 2:
  programa = input("Ingrese el sofware que quieres buscar: ")
  print("---Resultados---")
  encontrado = False
  for i in range(len(computadoras)):
    if programa.lower() in software[i].lower():
      print("Aula: ", aulas[i])
      print("ID", computadoras[i])
      print("Software: ", software[i])
      print("Estado: ", estados[i])
      encontrado = True
  if encontrado == False:
    print("No hay computadoras con ese software")
# Out:
# ...
#    SISTEMAS DE PRESTAMOS
# ...
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservavión
# 6. Agregar computadora
# 7. Salir
# Seleccione una opción: 2
# ...
# Ingrese el sofware que quieres buscar: Python
# ---Resultados---
# Aula:  LC1
# ID PC-LC1-01
# Software:  Python, VS Code
# Estado:  Disponible
# Aula:  LC1
# ID PC-LC1-02
# Software:  Python, Java VS Code
# Estado:  Prestada
# Aula:  LC2
# ID PC-LC2-01
# Software:  Python, VS Code
# Estado:  Disponible
# Aula:  LC2
# ID PC-LC2-02
# Software:  Python, Java VS Code
# Estado:  Prestada
# Aula:  LC3
# ID PC-LC3-01
# Software:  Python, VS Code
# Estado:  Disponible
# Aula:  LC3
# ID PC-LC3-02
# Software:  Python, Java VS Code
# Estado:  Prestada
# Aula:  LC3
# ID PC-LC3-04
# Software:  Python, VS Code
# Estado:  Mantenimiento
